# %%
from bs4 import BeautifulSoup
import requests

url = 'https://www.iranjib.ir/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
header_div = soup.find('div', id='column2')
news_div = header_div.find_all('h3')
for i in news_div:
    print(f'news name : {i.get_text()}\nlink : {i.find('a').get('href')}')

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://news.google.com/home?hl=en-US&gl=US&ceid=US:en'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
header_div = soup.find('div', class_='Ly25Ed')
news_div = header_div.find_all('div', class_='KDoq1')
for i in news_div:
    print(f'name : {i.find('span').get_text()}\nlink : https://news.google.com/home?hl=en-US&gl=US&ceid=US:en{i.find('a').get('href')}')
# Out:
# name : Backcountry skiers missing after avalanche near Castle Peak chevron_right
# link : https://news.google.com/home?hl=en-US&gl=US&ceid=US:en./stories/CAAqNggKIjBDQklTSGpvSmMzUnZjbmt0TXpZd1NoRUtEd2pjMHZISEVCR0g0M0puR0h3M3FpZ0FQAQ?hl=en-US&gl=US&ceid=US%3Aen
# name : More
# link : https://news.google.com/home?hl=en-US&gl=US&ceid=US:en./read/CBMiqwFBVV95cUxPNzVjOWJpRy1QMTl1Y0VYQ3dMVDFfRS1QNlNybDByb3M4TFMwZlllNnl3RTJrN0syTmN1NHljMFRrTHNvaVZtdDlVVkl1LWp1TE9KRzd3V0NpQV9jcnhfZHh6eTlwUGRueWh0dG10X29iZ0wwdTl0WVpsY0puWTdEN0ljZnQtN216amEzZ0NxS0lOdnNqbGNCTDNjWDQydDMybC1DYUJZNnNCaVk?hl=en-US&gl=US&ceid=US%3Aen
# name : More
# link : https://news.google.com/home?hl=en-US&gl=US&ceid=US:en.?hl=en-US&gl=US&ceid=US%3Aen
# name : More
# link : https://news.google.com/home?hl=en-US&gl=US&ceid=US:en....?hl=en-US&gl=US&ceid=US%3Aen

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://www.tabnak.ir/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
special_news_div_bs4 = soup.find('div', id='specialNewsH')
h2 = special_news_div_bs4.find_all('h2')
for each in h2:
    print(f'news name : {each.find('a').get_text()}\nlink : https://www.tabnak.ir{each.find('a').get('href')}')

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://www.tabnak.ir/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
header_div = soup.find(class_='gutter_main serviceColMain')
h3s = header_div.find_all('h3')
for i in h3s:
    print(
        f'name : {i.get_text()}\nlink : https://www.tabnak.ir{i.find('a').get('href')}')
# Out:
# name :
#  جدایی اسکوچیچ شبیه نکونام با دلایل متفاوت و فرمولی ثابت؛ رونمایی از پشت پرده‌ها در آسیا!
#
# link : https://www.tabnak.ir/fa/news/1358389/اسکوچیچ-و-تصمیم-مشابه-نکونام-در-آسیا
# name :
#  جنگ در خلیج فارس؛ سناریوی تقابل دریایی و هدف قرار دادن ناوهای آمریکایی با موشک‌های نسل جدید ایران
#
# link : https://www.tabnak.ir/fa/news/1358359/دژ-متحرک-آمریکا-در-تیررس-قاسم-بصیر
# name :
#  مذاکره همراه با تهدید نتیجه نمی‌دهد / توان دفاعی ایران خط قرمز ماست
#
# link : https://www.tabnak.ir/fa/news/1358299/مذاکره-همراه-با-تهدید-نتیجه-نمی‌دهد-توان-دفاعی-ایران-خط-قرمز-ماست
